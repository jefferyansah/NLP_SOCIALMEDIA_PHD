# %%
#Average Accuracy

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]
knn =[84.27,77.55,78.34,82.69, 87.71]
svm =[86.27,75.55,77.47,82.69, 87.72]
bsl =[78.96,74.55,74.41,76.22, 78.86]
vbm =[71.27,71.16,73.33,69.11,74.86]
fxknn =[81.94, 81.00, 78.37, 78.12, 80.38]
fxsvm = [81.70, 80.94, 73.38, 79.23, 80.38]

plt.ylim(ymax = 100, ymin = 65) #set limist for axes
pylab.plot(x, knn, '-g',  label='KNN', marker='o', linestyle='-')
pylab.plot(x, svm, '-k',  label='SVM', marker='x', linestyle='-')
pylab.plot(x, bsl, '-r',  label='Baseline', marker='^', linestyle='-')
pylab.plot(x, vbm, '-b',  label='VolumeBased', marker='^', linestyle='-')
pylab.plot(x, fxknn, '-g',  label='FeatureSelectKNN', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='FeatureSelectSVM', marker='x', linestyle='-')

plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('Average Acurracy on LeadTime 1')
plt.grid()
#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper right', ncol=1, bbox_to_anchor=(0.5, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]
knn =[81.90,81.26,85.6,81.18, 80.38]
svm =[82.56,84.34,86.96,79.54,80.95]
bsl =[77.98,77.66,84.40,77.76,77.59]
vbm =[66.62,71.85,72.39,73.83,71.40]
fxknn = [83.66, 83.66, 87.03, 81.20, 80.94]
fxsvm = [81.20, 83.66, 87.02, 81.20, 80.94]

pylab.plot(x, knn, '-g',  label='KNN', marker='o', linestyle='-')
pylab.plot(x, svm, '-k',  label='SVM', marker='x', linestyle='-')
pylab.plot(x, bsl, '-r',  label='Baseline', marker='^', linestyle='-')
pylab.plot(x, vbm, '-b',  label='VolumeBased', marker='*', linestyle='-')
pylab.plot(x, fxknn, '-g',  label='FeatureSelectKNN', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='FeatureSelectSVM', marker='x', linestyle='-')

#plt.yticks(0, 100, 5)
plt.ylim(ymax = 90, ymin = 65)
plt.grid()
plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('State: Average Accuracy on LeadTime 2')

#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper left', ncol=1, bbox_to_anchor=(0.5, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]
knn =[75.90,76.35,78.23,78.96, 81.02]
svm =[76.75,78.35,81.2,79.35,82.44]
bsl =[73.98,75.66,74.40,75.76,77.59]
vbm =[67.34,73.35,73.43,65.54,66.38]
fxknn =[83.19, 79.71, 83.27, 77.36, 79.30]
fxsvm = [83.90, 79.02, 81.92, 78.08, 80.37]

pylab.plot(x, knn, '-g',  label='KNN', marker='o', linestyle='-')
pylab.plot(x, svm, '-k',  label='SVM', marker='x', linestyle='-')
pylab.plot(x, bsl, '-r',  label='Baseline', marker='^', linestyle='-')
pylab.plot(x, vbm, '-b',  label='VolumeBased', marker='*', linestyle='-')
pylab.plot(x, fxknn, '-g',  label='FeatureSelectKNN', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='FeatureSelectSVM', marker='x', linestyle='-')

plt.ylim(ymax = 90, ymin = 65)
plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('State: Average Accuracy on LeadTime 3')
plt.grid()
#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper right', ncol=1, bbox_to_anchor=(0.3, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()

# %% [markdown]
# # Roc Plots

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]

fxknn = [0.56, 0.66, 0.52, 0.52, 0.56]
fxsvm = [0.50, 0.50, 0.51, 0.52, 0.50]


pylab.plot(x, fxknn, '-b',  label='fxknn ROC', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='fxsvm ROC', marker='x', linestyle='-')

plt.ylim(ymax = 1.00, ymin = 0.25)
plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('State: Average ROC Area on LeadTime 1')
plt.grid()
#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper right', ncol=1, bbox_to_anchor=(0.3, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]

fxknn = [0.67, 0.61, 0.55, 0.67, 0.53]
fxsvm = [0.50, 0.50, 0.50, 0.50, 0.55]


pylab.plot(x, fxknn, '-b',  label='fxknn ROC', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='fxsvm ROC', marker='x', linestyle='-')

plt.ylim(ymax = 1.00, ymin = 0.25)
plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('State: Average ROC Area on LeadTime 2')
plt.grid()
#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper right', ncol=1, bbox_to_anchor=(0.3, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()

# %%
import matplotlib.pyplot as plt
import pylab

x =[1,2,3,4,5]

fxknn = [0.63, 0.57, 0.66, 0.53, 0.61]
fxsvm = [0.50, 0.50, 0.56, 0.50, 0.50]


pylab.plot(x, fxknn, '-b',  label='fxknn ROC', marker='^', linestyle='-')
pylab.plot(x, fxsvm, '-k',  label='fxsvm ROC', marker='x', linestyle='-')

plt.ylim(ymax = 1.00, ymin = 0.25)
plt.xlabel("Window")
plt.ylabel("Model Accuracy")
plt.title('State: Average ROC Area on LeadTime 3')
plt.grid()
#pylab.plot(days, coalmine, '-k', label='#coal')
#pylab.plot(days, keepit, '-g', label='#coalpower', marker='.')

pylab.legend(loc='upper right', ncol=1, bbox_to_anchor=(0.3, 0.99), fontsize='small')
#pylab.plot(my_xticks, fontsize='small')
plt.show()
