# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\New folder\\working scripts\\retweet scripts\\RTNetwork.csv") #loads the csv correctly
ds
# Out:
#                                                  tweet  \
# 0                                             bodyText
# 1    RT @CorruptNSW: #nswpol #auspol #lnpfail \r\n#...
# 2    RT @1EarthMedia: Swift\r\nAnd\r\nNasty\r\nTypi...
# 3    RT @StopShenhua: "So much is being sacrificed ...
# 4    RT @jameswhel: Talking #cleanair with Dr David...
# 5    #Aust. can learn a lesson from the US's approa...
# 6    RT @insideclimate: From over the weekend: Hund...
# 7    RT @AustralisTerry: Is it a #coal hole?\r\nIs ...
# 8    RT @MikeHudema: POW! #China to close more than...
# 9    RT @TheFacelessmen: S. Stealing \r\nA. Austral...
# 10   From over the weekend: Hundreds protest downto...
# 11   RT @LongwallNews: .@bhpbilliton #coal sinks in...
# 12   RT @CenterForBioDiv: China to close more than ...
# 13   RT @AustralisTerry: Def several #koalas in tha...
# 14   RT @market_forces: Vox on the fall of US #coal...
# 15   RT @TradersCom: Farmers take #coal campaign to...
# ...

# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\New folder\\working scripts\\follower scripts\\tweet\\tweet\\newfollower_cascade.csv") #loads the csv correctly
ds
# Out:
#                                                  tweet  \
# 0                                             bodyText
# 1    RT @CorruptNSW: #nswpol #auspol #lnpfail \r\n#...
# 2    RT @1EarthMedia: Swift\r\nAnd\r\nNasty\r\nTypi...
# 3    RT @StopShenhua: "So much is being sacrificed ...
# 4    RT @jameswhel: Talking #cleanair with Dr David...
# 5    #Aust. can learn a lesson from the US's approa...
# 6    RT @insideclimate: From over the weekend: Hund...
# 7    RT @AustralisTerry: Is it a #coal hole?\r\nIs ...
# 8    RT @MikeHudema: POW! #China to close more than...
# 9    RT @TheFacelessmen: S. Stealing \r\nA. Austral...
# 10   From over the weekend: Hundreds protest downto...
# 11   RT @LongwallNews: .@bhpbilliton #coal sinks in...
# 12   RT @CenterForBioDiv: China to close more than ...
# 13   RT @AustralisTerry: Def several #koalas in tha...
# 14   RT @market_forces: Vox on the fall of US #coal...
# 15   RT @TradersCom: Farmers take #coal campaign to...
# ...

# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\New folder\\working scripts\\follower scripts\\tweet\\tweet\\newretweet.csv") #loads the csv correctly
ds
# Out:
#                                                  tweet  \
# 0                                             bodyText
# 1    RT @CorruptNSW: #nswpol #auspol #lnpfail \r\n#...
# 2    RT @1EarthMedia: Swift\r\nAnd\r\nNasty\r\nTypi...
# 3    RT @StopShenhua: "So much is being sacrificed ...
# 4    RT @jameswhel: Talking #cleanair with Dr David...
# 5    #Aust. can learn a lesson from the US's approa...
# 6    RT @insideclimate: From over the weekend: Hund...
# 7    RT @AustralisTerry: Is it a #coal hole?\r\nIs ...
# 8    RT @MikeHudema: POW! #China to close more than...
# 9    RT @TheFacelessmen: S. Stealing \r\nA. Austral...
# 10   From over the weekend: Hundreds protest downto...
# 11   RT @LongwallNews: .@bhpbilliton #coal sinks in...
# 12   RT @CenterForBioDiv: China to close more than ...
# 13   RT @AustralisTerry: Def several #koalas in tha...
# 14   RT @market_forces: Vox on the fall of US #coal...
# 15   RT @TradersCom: Farmers take #coal campaign to...
# ...

# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\New folder\\output.csv") #loads the csv correctly
ds
# Out:
#                                                  tweet  \
# 0                                             bodyText
# 1    RT @StopShenhua: "The failure of the people we...
# 2    RT @StopShenhua: "The risks in terms of ground...
# 3    RT @market_forces: NSW court rules that Shenhu...
# 4    #Shenhua #coalmine: Controversial #LiverpoolPl...
# 5    #AngloAmerican has announced it will sell off ...
# 6    RT @350Australia: Adani Group's Aust #coal min...
# 7    Hogsback urges #coal companies to hang around....
# 8    RT @StopShenhua: "I want future generations to...
# 9    RT @AustralisTerry: Even the great US weatherv...
# 10   RT @Valen_of_Minbar: Not good for humanity #au...
# 11   RT @CorruptNSW: #nswpol #auspol #lnpfail #Shen...
# 12   RT @1EarthMedia: Gomeroi people fear sacred si...
# 13   RT @maxphillips: Deluded: Josh Frydenberg says...
# 14   RT @StopShenhua: "This is not a mine site; it ...
# 15   RT @CSGstinks: Bum. RT @EDONSW Breaking: court...
# ...

# %%
import numpy as np
import pandas as pd
import csv

#data = np.loadtxt("C:\\Users\\ansja001\\Desktop\\algorithm.csv")
with open("C:\\Users\\ansja001\\Desktop\\loadme.csv", 'r') as f:
    data = [i.split(",") for i in f.read().split()]
    #print(data)
type(data)
df = pd.DataFrame(data)
df
#df.describe()
# Out:
#           0           1         2
# 0     INDEX         IDS  CASCADES
# 1      9525  1404087277      C-98
# 2      9523   568967091      C-97
# 3      9524   252420272      C-97
# 4      9487  3012889453      C-97
# 5      9485  1574214456      C-97
# 6      9486  1320230766      C-97
# 7      9484   602561729      C-97
# 8      9482  1708574071      C-97
# 9      9483  1642193124      C-97
# 10     9481   258987105      C-97
# 11     9490  3185773574      C-96
# 12     9491   594628359      C-96
# 13     9492  3230171281      C-96
# 14     9493  1731244046      C-96
# 15     9494    15061618      C-95
# 16     9496   394022301      C-95
# 17     9495   394022301      C-95
# 18     9498    7.05E+17      C-95
# 19     9497   142258399      C-95
# 20     9499  1208242926      C-95
# 21     9500   464578359      C-95
# 22     9501   594628359      C-95
# 23     9502  1328199997      C-95
# 24     9503  3354099657      C-95
# 25     9504  2456098358      C-95
# ...

# %%
import pandas as pd
import numpy as np
import sql


ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\realFinalNHB - Copy.csv") #loads the csv correctly
ds
# Out:
#      Unnamed: 0     AUTHOR ID              DATE  \
# 0          6277  2.418857e+09   27/02/2016 0:08
# 1          6278  5.797749e+08   27/02/2016 0:12
# 2          6279  2.681948e+09   27/02/2016 0:12
# 3          6280  3.147339e+09   27/02/2016 0:15
# 4          6281  1.574530e+09   27/02/2016 0:22
# 5          6282  2.955494e+09   27/02/2016 0:26
# 6          6283  1.574530e+09   27/02/2016 0:32
# 7          6284  3.597627e+07   27/02/2016 0:33
# 8          6285  3.145840e+09   27/02/2016 0:37
# 9          6286  2.646668e+09   27/02/2016 0:41
# 10         6287  1.648840e+09   27/02/2016 0:43
# 11         6288  8.990323e+07   27/02/2016 0:45
# 12         6289  8.990323e+07   27/02/2016 1:14
# 13         6290  2.570612e+09   27/02/2016 1:28
# 14         6291  9.211867e+08   27/02/2016 1:37
# 15         6292  1.814291e+08   27/02/2016 4:25
# 16         6293  1.684101e+09   27/02/2016 5:19
# 17         6294  4.110462e+08   27/02/2016 5:28
# ...

# %%
#print(ds.loc[ds['DATE'] == '%27/02/2016%']) #
#my = print(ds[ds['DATE'].str.contains('27/02/2016')])

day1 = ds[ds['DATE'].str.contains('1/03/2016', na = False)]
cd1 = day1[day1['CASCADES'].str.contains('CASCADE', na = False)]
tcd1 = pd.value_counts(cd1['CASCADES'].values, sort= False)
k1 = tcd1.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k1.columns = ['Cascade-ID','Cascade Size']
k1.to_csv('day1cascade.csv')

# %%
day2 = ds[ds['DATE'].str.contains('2/03/2016', na = False)]
cd2 = day2[day2['CASCADES'].str.contains('CASCADE', na = False)]
tcd2 = pd.value_counts(cd2['CASCADES'].values, sort= False)
k2 = tcd2.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k2.columns = ['Cascade-ID','Cascade Size']
k1.to_csv('day2cascade.csv')

# %%
day3 = ds[ds['DATE'].str.contains('3/03/2016', na = False)]
cd3 = day3[day3['CASCADES'].str.contains('CASCADE', na = False)]
tcd3 = pd.value_counts(cd3['CASCADES'].values, sort= False)
k3 = tcd3.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k3.columns = ['Cascade-ID','Cascade Size']
k3.to_csv('day3cascade.csv')

# %%
day4 = ds[ds['DATE'].str.contains('4/03/2016', na = False)]
cd4 = day4[day4['CASCADES'].str.contains('CASCADE', na = False)]
tcd4 = pd.value_counts(cd4['CASCADES'].values, sort= False)
k4 = tcd4.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k4.columns = ['Cascade-ID','Cascade Size']
k4.to_csv('day4cascade.csv')

# %%
day5 = ds[ds['DATE'].str.contains('5/03/2016', na = False)]
cd5 = day5[day5['CASCADES'].str.contains('CASCADE', na = False)]
tcd5 = pd.value_counts(cd5['CASCADES'].values, sort= False)
k5 = tcd5.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k5.columns = ['Cascade-ID','Cascade Size']
k5.to_csv('day5cascade.csv')

# %%
day6 = ds[ds['DATE'].str.contains('6/03/2016', na = False)]
cd6 = day6[day6['CASCADES'].str.contains('CASCADE', na = False)]
tcd6 = pd.value_counts(cd6['CASCADES'].values, sort= False)
k6 = tcd6.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k6.columns = ['Cascade-ID','Cascade Size']
k6.to_csv('day6cascade.csv')

# %%
day6 = ds[ds['DATE'].str.contains('6/03/2016', na = False)]
cd6 = day6[day6['CASCADES'].str.contains('CASCADE', na = False)]
tcd6 = pd.value_counts(cd6['CASCADES'].values, sort= False)
k6 = tcd6.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k6.columns = ['Cascade-ID','Cascade Size']
k6.to_csv('day6cascade.csv')

# %%
day7 = ds[ds['DATE'].str.contains('7/03/2016', na = False)]
cd7 = day7[day7['CASCADES'].str.contains('CASCADE', na = False)]
tcd7 = pd.value_counts(cd7['CASCADES'].values, sort= False)
k7 = tcd7.to_frame().reset_index() #cOUNTS THE FREQUENCY FOR THE CASCADES #DAILY
#final = tcd1.columns = ['Cascade-ID','Cascade Size']
k7.columns = ['Cascade-ID','Cascade Size']
k7.to_csv('day7cascade.csv')

# %%
lol1 = pd.value_counts(df[3].values, sort= False)
lol1
type(lol1)
lol1.tolist()
#len(lol1)
# Out:
# [2,
#  21,
#  27,
#  65,
#  16,
#  1,
#  20,
#  17,
#  8,
#  6,
#  16,
#  1,
#  3,
#  20,
#  6,
#  4,
#  3,
#  1,
#  15,
#  4,
#  12,
#  4,
#  7,
#  3,
#  8,
#  1,
#  23,
#  37,
#  1,
#  4,
#  19,
#  131,
#  13,
#  1,
#  27,
#  16,
#  6,
#  4,
#  1,
#  3,
#  9,
#  3,
#  31,
#  1,
#  3,
#  83,
#  22,
#  1,
#  11,
#  38,
#  1,
#  2,
#  88,
#  41,
#  59,
#  2,
#  4,
#  5,
#  141,
#  2,
#  7,
#  6,
#  10,
#  4,
#  2,
#  3,
#  24,
#  1,
#  16,
#  17,
#  1,
#  10,
#  34,
#  2,
#  3,
#  36,
#  2,
#  2,
#  8,
#  36,
#  4,
#  4,
#  19,
#  33,
#  2,
#  2,
#  13,
#  3,
#  12,
#  1,
#  40,
#  1,
#  5,
#  18,
#  1,
#  13,
#  2,
#  30,
#  20,
#  1,
#  1,
#  1,
#  1,
#  1,
#  37,
#  11,
#  29,
#  14,
#  83,
#  15,
#  2,
#  4,
#  17,
#  26,
#  1,
#  31,
#  5,
#  18,
#  2,
#  22,
#  7,
#  3,
#  20,
#  5,
#  27,
#  1,
#  2,
#  6,
#  27,
#  1,
#  1,
#  5,
#  2,
#  2,
#  1,
#  23,
#  8,
#  35,
#  6,
#  4,
#  6,
#  46,
#  144,
#  32,
#  43,
#  22,
#  9,
#  14]

# %%
lol1
# Out:
# "C-122         2
# C-117         21
# C-140         27
# C-57          65
# C-160         16
# C-89           1
# C-74          20
# C-59          17
# C-94           8
# "C-17          6
# C-84          16
# CASCADES       1
# C-125          3
# C-67          20
# C-166          6
# "C-120         4
# C-115          3
# C-40           1
# C-22          15
# C-150          4
# C-3           12
# C-170          4
# C-76           7
# C-118          3
# C-73           8
# C-68           1
# C-162         23
# C-48          37
# C-81           1
# C-168          4
#             ...
# C-15           2
# C-62          22
# C-20           7
# C-31           3
# C-139         20
# C-167          5
# C-158         27
# C-124          1
# C-36           2
# "C-163         6
# C-63          27
# "C-121ces      1
# C-19           1
# C-82           5
# C-47           2
# C-41           2
# C-145          1
# C-153         23
# C-157          8
# C-92          35
# C-144          6
# ...

# %%
my1 = lol1
#pandas.series.to_frame(my1)
dof = my1.to_frame().reset_index()
dof
# Out:
#          index    0
# 0       "C-122    2
# 1        C-117   21
# 2        C-140   27
# 3         C-57   65
# 4        C-160   16
# 5         C-89    1
# 6         C-74   20
# 7         C-59   17
# 8         C-94    8
# 9        "C-17    6
# 10        C-84   16
# 11    CASCADES    1
# 12       C-125    3
# 13        C-67   20
# 14       C-166    6
# 15      "C-120    4
# 16       C-115    3
# 17        C-40    1
# 18        C-22   15
# 19       C-150    4
# 20         C-3   12
# 21       C-170    4
# 22        C-76    7
# 23       C-118    3
# 24        C-73    8
# 25        C-68    1
# 26       C-162   23
# 27        C-48   37
# 28        C-81    1
# 29       C-168    4
# ..         ...  ...
# 118       C-15    2
# 119       C-62   22
# 120       C-20    7
# 121       C-31    3
# 122      C-139   20
# 123      C-167    5
# 124      C-158   27
# 125      C-124    1
# 126       C-36    2
# 127     "C-163    6
# 128       C-63   27
# 129  "C-121ces    1
# 130       C-19    1
# ...

# %%
#df["D"] = m[df.A]
#df['new_col'] = lol1.values
dof.columns = ['Cascade-ID','Cascade Size']
dof

# %%
dof.to_csv('timeMars1.csv')

# %%
import pandas as pd
import numpy as np
import sql


ds = pd.read_csv("C:\\Users\\ansja001\\Desktop\\Coal protest Dataset\\experiment for 7days\\frequencytable.csv") #loads the csv correctly
lol1 = ds['Cascade-ID'].unique()
lol1

myList = lol1.tolist()
type(myList)
toDf = pd.DataFrame(myList)
toDf
# Out:
#                      0
# 0         CASCADEMAR95
# 1         CASCADEMAR94
# 2         CASCADEMAR93
# 3         CASCADEMAR92
# 4         CASCADEMAR91
# 5         CASCADEMAR90
# 6        CASCADEMAR84
# 7         CASCADEMAR79
# 8         CASCADEMAR77
# 9         CASCADEMAR75
# 10        CASCADEMAR74
# 11        CASCADEMAR67
# 12        CASCADEMAR66
# 13        CASCADEMAR65
# 14        CASCADEMAR58
# 15        CASCADEMAR56
# 16       CASCADEMAR117
# 17       CASCADEMAR108
# 18       CASCADEMAR107
# 19       CASCADEMAR106
# 20       CASCADEMAR105
# 21       CASCADEMAR104
# 22          CASCADE429
# 23          CASCADE389
# 24          CASCADE281
# 25          CASCADE171
# 26          CASCADE167
# 27          CASCADE138
# 28          CASCADE116
# 29          CASCADE100
# ..                 ...
# 45       CASCADE534_19
# 46          CASCADE124
# 47       CASCADE534_11
# 48     CASCADEMAR122\r
# 49           CASCADE69
# 50       CASCADE534_14
# 51        CASCADE534_5
# 52        CASCADEMAR69
# ...

# %%
import pandas as pd
import numpy as np
import sql

ds8 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar8.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract8 = pd.value_counts(ds8['bodyText'].values, sort= False)
extract8
my8 = extract8
#pandas.series.to_frame(my1)
dsf8 = my1.to_frame().reset_index()
dsf8.columns = ['Cascade-ID','Cascade Size']
dsf8.to_csv('RTCascade_Day8.csv')

# %%
import pandas as pd
import numpy as np
import sql


ds7 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar7.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract7 = pd.value_counts(ds7['bodyText'].values, sort= False)
extract7
my7 = extract7
#pandas.series.to_frame(my1)
dsf7 = my7.to_frame().reset_index()
dsf7.columns = ['Cascade-ID','Cascade Size']
dsf7.to_csv('RTCascade_Day7.csv')

# %%
ds6 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar6.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract6 = pd.value_counts(ds6['bodyText'].values, sort= False)
extract6
my6 = extract6
#pandas.series.to_frame(my1)
dsf6 = my6.to_frame().reset_index()
dsf6.columns = ['Cascade-ID','Cascade Size']
dsf6.to_csv('RTCascade_Day6.csv')

# %%
ds5 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar5.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract5 = pd.value_counts(ds5['bodyText'].values, sort= False)
extract5
my5 = extract5
#pandas.series.to_frame(my1)
dsf5 = my5.to_frame().reset_index()
dsf5.columns = ['Cascade-ID','Cascade Size']
dsf5.to_csv('RTCascade_Day5.csv')

# %%
ds4 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar4.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract4 = pd.value_counts(ds4['bodyText'].values, sort= False)
extract4
my4 = extract4
#pandas.series.to_frame(my1)
dsf4 = my4.to_frame().reset_index()
dsf4.columns = ['Cascade-ID','Cascade Size']
dsf4.to_csv('RTCascade_Day4.csv')

# %%
ds3 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar3.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract3 = pd.value_counts(ds3['bodyText'].values, sort= False)
extract3
my3 = extract3
#pandas.series.to_frame(my1)
dsf3 = my3.to_frame().reset_index()
dsf3.columns = ['Cascade-ID','Cascade Size']
dsf3.to_csv('RTCascade_Day3.csv')

# %%
ds2 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar2.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract2 = pd.value_counts(ds2['bodyText'].values, sort= False)
extract2
my2 = extract2
#pandas.series.to_frame(my1)
dsf2 = my2.to_frame().reset_index()
dsf2.columns = ['Cascade-ID','Cascade Size']
dsf2.to_csv('RTCascade_Day2.csv')

# %%
ds1 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\tiMESERIES DATA\\Cascade_NewCastle Habour\\Mar1.csv") #loads the csv correctly
#ds.drop_duplicates()
#ds['bodyText']
#ds.drop_duplicates(['bodyText']) Working perfecrly well.. shows tweets that can be counted cascades
extract1 = pd.value_counts(ds1['bodyText'].values, sort= False)
extract1
my1 = extract1
#pandas.series.to_frame(my1)
dsf1 = my1.to_frame().reset_index()
dsf1.columns = ['Cascade-ID','Cascade Size']
dsf1.to_csv('RTCascade_Day1.csv')

# %% [markdown]
# # Read And Analyze 7- Day Cascade Data

# %%
# first Analyze old Cascades 
old_csd = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\OldRetweet_Cascades\\freq_addedcombinedcascade.csv")

p1 = old_csd.dropna()
p1

p2 = old_csd.drop_duplicates(['Cascade-ID'])
p2
# Out:
#                                             Cascade-ID  day1cascade  \
# 0                                                  NaN          NaN
# 1                                         CASCADEMAR95          3.0
# 3                                         CASCADEMAR94         19.0
# 5                                         CASCADEMAR93          1.0
# 7                                         CASCADEMAR92         15.0
# 9                                         CASCADEMAR91          2.0
# 11                                        CASCADEMAR90          1.0
# 13                               CASCADEMAR84 @FoEAus?         41.0
# 15                                        CASCADEMAR79         18.0
# 17                                        CASCADEMAR77          1.0
# 19                                        CASCADEMAR75          6.0
# 21                                        CASCADEMAR74          1.0
# 23                                        CASCADEMAR67         22.0
# ...

# %%
#filter1 = mydrop[mydrop['Total Size of Cascade'] > 0]   # Working: Filter Cascade where size is greater than 1

#try droping to get only cascades that grew through all the 7 days
#mydrop2 = p2.dropna()
sfilter = p2[p2['Total Cascade for 7 Days'] > 5]

sfilter
# Out:
#                                             Cascade-ID  day1cascade  \
# 3                                         CASCADEMAR94         19.0
# 5                                         CASCADEMAR93          1.0
# 7                                         CASCADEMAR92         15.0
# 9                                         CASCADEMAR91          2.0
# 13                               CASCADEMAR84 @FoEAus?         41.0
# 15                                        CASCADEMAR79         18.0
# 19                                        CASCADEMAR75          6.0
# 23                                        CASCADEMAR67         22.0
# 25                                        CASCADEMAR66          8.0
# 27                                        CASCADEMAR65          2.0
# 29                                        CASCADEMAR58          6.0
# 31                                        CASCADEMAR56          2.0
# 33                                       CASCADEMAR117         26.0
# ...

# %% [markdown]
# # Analysis for New Cascades

# %%
d

#mydrop = new_csd.dropna()

mydrop= new_csd.drop_duplicates(['Cascade-ID'])
mydrop
# Out:
#                                              Cascade-ID  RTCascade_Day1  \
# 0                                                   NaN             NaN
# 1     'Disturbing': CSIRO units copping cuts to 'wea...             1.0
# 3     RT @pandymonium01: #qldpol #nswpol #actpol #sp...             2.0
# 5     by me: #Peabody Energy teeters on the edge of ...             1.0
# 7     RT @StopShenhua: "If we're not 100% certain th...             2.0
# 9     Our Addiction To Coal Is Forcing Us To Farm Co...             1.0
# 11    @amygillettfdn will you just fuck off. You're ...             1.0
# 13    @GregHuntMP we are not your gasfield!\r\nTurns...             1.0
# 15    RT @ProfRayWills: #India's 2016 #budget target...             3.0
# 17    RT @StopShenhua: ?I?m not against mining but t...             5.0
# 19    RT @CSGOLegit: ???  GIVEAWAY  ???\r\n? Bowie K...             1.0
# 21    RT @MATOGI: URGENT PETITION calling on the @NH...             1.0
# ...

# %%
#trydf = mydrop['Total Size of Cascade' != 0]
#trydf
#mydrop.query('Total Size of Cascade' != 0)

#dfx = mydrop[~(mydrop == 0).any(axis=1)]
#dfx
filter1 = mydrop[mydrop['Total Size of Cascade'] > 2]   # Working: Filter Cascade where size is greater than 1

#try droping to get only cascades that grew through all the 7 days
#mydrop2 = filter1.dropna()
filter1
#mydrop2   

# REsults shows that only two cascades survived through out the seven days
#the insights may be that while page initiated cascade are able to generate large cascades, their lifespan are short lived.
# Out:
#                                              Cascade-ID  RTCascade_Day1  \
# 15    RT @ProfRayWills: #India's 2016 #budget target...             3.0
# 17    RT @StopShenhua: ?I?m not against mining but t...             5.0
# 27    RT @StopShenhua: "You cannot put a price on th...             4.0
# 35    RT @350Australia: Tks @AustralianStory for inc...             2.0
# 41    RT @StopShenhua: "It's wrong to push the regio...             3.0
# 73    RT @MikeHudema: A new wave of #climate insurge...             4.0
# 89    RT @star_observer: Rainbow Muslims to make a s...             2.0
# 97    RT @PennySharpemlc: I will miss @LindaBurneyMP...             8.0
# 143   RT @faully33: For the Record Baird is putting ...             4.0
# 145   RT @StopShenhua: The world?s biggest source of...            17.0
# 159   RT @matt_barrie: Please @DanielAndrewsMP, can ...            12.0
# 163   RT @AustralisTerry: For people to bolt on to m...             4.0
# ...

# %%
filter1.to_csv('Dailygrowth_plot.csv')

# %%
import pandas as pd
import pandas as pd
import numpy as np
import sql
#old_csd = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\OldRetweet_Cascades\\freq_addedcombinedcascade.csv")
lil1 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\Coal protest Dataset\\newRetweet_Cascades_2-03-17\\further prunning\\FeatureSet.csv")
lil1
# Out:
#      Unnamed: 0                                         Cascade-ID  \
# 0            15  RT @ProfRayWills: #India's 2016 #budget target...
# 1            17  RT @StopShenhua: ?I?m not against mining but t...
# 2            27  RT @StopShenhua: "You cannot put a price on th...
# 3            35  RT @350Australia: Tks @AustralianStory for inc...
# 4            41  RT @StopShenhua: "It's wrong to push the regio...
# 5            73  RT @MikeHudema: A new wave of #climate insurge...
# 6            89  RT @star_observer: Rainbow Muslims to make a s...
# 7            97  RT @PennySharpemlc: I will miss @LindaBurneyMP...
# 8           143  RT @faully33: For the Record Baird is putting ...
# 9           145  RT @StopShenhua: The world?s biggest source of...
# 10          159  RT @matt_barrie: Please @DanielAndrewsMP, can ...
# 11          163  RT @AustralisTerry: For people to bolt on to m...
# 12          175  RT @AustralisTerry: #LiverpoolPlains locals ca...
# ...

# %%
lil1[lil1['Cascade-ID'].str.startswith("RT")] #works well
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Cascade-ID, RTCascade_Day1, RTCascade_Day2, RTCascade_Day3, RTCascade_Day4, RTCascade_Day5, RTCascade_Day6, RTCascade_Day7, Total Size of Cascade, Cascade Duration, Growth Rate(within 7Days), Growth Rate(within Life Span), No. of Followers  of Root ]
# Index: []

# %%
forIDs = lil1[lil1['Total Size of Cascade'] > 10]
forIDs
# Out:
#      Unnamed: 0                                         Cascade-ID  \
# 9           145  RT @StopShenhua: The world?s biggest source of...
# 10          159  RT @matt_barrie: Please @DanielAndrewsMP, can ...
# 12          175  RT @AustralisTerry: #LiverpoolPlains locals ca...
# 15          209  RT @JoJamesHolden: @GregHuntMP we are not your...
# 16          251  RT @AustralisTerry: For people to bolt on to m...
# 17          257  RT @StopShenhua: Farmers call for @TonyHWindso...
# 19          287  RT @CsgoImmerse: RE-TWEET AND FAV \r\r\nTHEN C...
# 21          305  RT @CsgoImmerse: RE-TWEET AND FAV \r\r\nTHEN C...
# 22          323  RT @larissawaters: Concern for #GreatBarrierRe...
# 23          329  RT @StopShenhua: "@The_Nationals in tying them...
# 26          367  RT @StopShenhua: "#Shenhua is well aware its p...
# 29          379  RT @StopShenhua: #LiverpoolPlains locals call ...
# 32          427  RT @AnnieKia: Plucky community takes mining gi...
# ...

# %%
forIDs.to_csv('Sizeless10.csv')

# %%
import pandas as pd
import pandas as pd
import numpy as np
import sql
#old_csd = pd.read_csv("C:\\Users\\ansja001\\Desktop\\\Coal protest Dataset\\OldRetweet_Cascades\\freq_addedcombinedcascade.csv")
corr1 = pd.read_csv("C:\\Users\\ansja001\\Desktop\\Coal protest Dataset\\newRetweet_Cascades_2-03-17\\corr.csv")
corr1
corr1.corr()
# Out:
#                                      ID  RTCascade_Day1  RTCascade_Day2  \
# ID                             1.000000        0.293690       -0.251876
# RTCascade_Day1                 0.293690        1.000000       -0.038703
# RTCascade_Day2                -0.251876       -0.038703        1.000000
# RTCascade_Day3                -0.103237       -0.279673        0.142408
# RTCascade_Day4                -0.123991       -0.106566        0.143517
# RTCascade_Day5                -0.171784        0.030463        0.117224
# RTCascade_Day6                -0.163958       -0.199238        0.192690
# RTCascade_Day7                -0.163958       -0.199238        0.192690
# Total Size of Cascade         -0.074327        0.292450        0.391167
# Cascade Duration              -0.553228       -0.292478        0.535654
# Growth Rate(within 7Days)     -0.074327        0.292450        0.391167
# Growth Rate(within Life Span)  0.468642        0.745668       -0.072422
#
# ...
