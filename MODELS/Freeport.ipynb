# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("new.csv") #loads the csv correctly
ds
# Out:
#            Date  freeport  size  total  Total No. Cascade  protested  \
# 0     1/01/2017         1   1.0    1.0                1.0          0
# 1     4/01/2017         1   1.0    1.0                1.0          0
# 2     5/01/2017        24  11.0    6.0               24.0          0
# 3     6/01/2017        32  11.0   11.0               32.0          0
# 4     7/01/2017         2   1.0    2.0                2.0          0
# 5     8/01/2017         1   1.0    1.0                1.0          0
# 6     9/01/2017        20  12.0    8.0               20.0          0
# 7    10/01/2017        22  10.0    3.0               12.0          0
# 8    11/01/2017         8   6.0    2.0                8.0          0
# 9    12/01/2017         6   1.0    5.0                5.0          0
# 10   13/01/2017        39  10.0   18.0               29.0          0
# 11   14/01/2017        27  11.0    6.0               16.0          0
# 12   16/01/2017         1   1.0    1.0                1.0          0
# ...

# %%
ds.describe()
# Out:
#           freeport        size       total  Total No. Cascade  protested  \
# count   110.000000  109.000000  109.000000         109.000000      110.0
# mean     66.463636   12.211009   23.834862          61.229358        0.0
# std     155.503484   34.975937   47.588809         147.592133        0.0
# min       1.000000    1.000000    1.000000           1.000000        0.0
# 25%       9.000000    2.000000    5.000000           6.000000        0.0
# 50%      22.000000    4.000000   10.000000          18.000000        0.0
# 75%      38.750000   10.000000   20.000000          34.000000        0.0
# max    1033.000000  336.000000  296.000000        1002.000000        0.0
#
#        gsr encoding     weights
# count    110.000000  110.000000
# mean       0.281818   28.181818
# std        0.743557   74.355726
# min        0.000000    0.000000
# 25%        0.000000    0.000000
# 50%        0.000000    0.000000
# 75%        0.000000    0.000000
# max        4.000000  400.000000

# %%
ds["size"]
# Out:
# 0       1.0
# 1       1.0
# 2      11.0
# 3      11.0
# 4       1.0
# 5       1.0
# 6      12.0
# 7      10.0
# 8       6.0
# 9       1.0
# 10     10.0
# 11     11.0
# 12      1.0
# 13      4.0
# 14      2.0
# 15      1.0
# 16      1.0
# 17      1.0
# 18      5.0
# 19      4.0
# 20      1.0
# 21      1.0
# 22      7.0
# 23      NaN
# 24      3.0
# 25      1.0
# 26      1.0
# 27      2.0
# 28      1.0
# 29      2.0
#        ...
# 80     13.0
# 81      9.0
# 82      2.0
# 83      7.0
# 84      3.0
# 85      7.0
# 86      5.0
# 87     14.0
# 88     12.0
# 89      4.0
# 90      3.0
# 91      3.0
# 92      2.0
# 93      2.0
# 94      1.0
# 95      7.0
# 96      4.0
# 97      1.0
# 98      9.0
# 99      2.0
# 100     8.0
# 101    14.0
# 102     3.0
# 103     7.0
# 104     4.0
# 105     8.0
# 106     2.0
# 107     1.0
# 108     2.0
# 109     2.0
# Name: size, dtype: float64

# %%
import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
#plt.figure( figsize=(20, 20), dpi=1000)
#ax.set_xticklabels(ds['Date'], fontsize=6)
lb =ds.plot(kind= 'line')
lb.show()
#plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-ce9450ecd4db> in <module>()
#       4 ax.set_xticklabels(ds['Date'], fontsize=6)
#       5 lb =ds.plot(kind= 'line')
# ----> 6 lb.show()
#       7 #plot.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
