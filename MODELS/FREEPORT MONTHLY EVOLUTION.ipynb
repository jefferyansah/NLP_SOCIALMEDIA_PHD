# %%
import numpy as np
import pandas as pd
import csv

ds = pd.read_csv("fp_hash_loc.csv") #loads the csv correctly
ds
# Out:
#       Unnamed: 0  Unnamed: 0.1                                 author  \
# 0              0             5            ['id:twitter.com:79004617']
# 1              3            59           ['id:twitter.com:267083380']
# 2              4            60           ['id:twitter.com:407047057']
# 3              5            62          ['id:twitter.com:2527838989']
# 4             11            70          ['id:twitter.com:3222096079']
# 5             14            78  ['id:twitter.com:729916352555683840']
# 6             15           118  ['id:twitter.com:807105917317545985']
# 7             16           119  ['id:twitter.com:807273017084506112']
# 8             19           122  ['id:twitter.com:807419327221624832']
# 9             20           123  ['id:twitter.com:807108629983674368']
# 10            21           125          ['id:twitter.com:2885810856']
# 11            22           126  ['id:twitter.com:807128059493040128']
# ...

# %%
loc_filter= ds.where(ds['time'].str.contains('2017-02')).dropna()
loc_filter.to_csv('fp_feb_evolve.csv') 
loc_filter
# Out:
#       Unnamed: 0  Unnamed: 0.1                                 author  \
# 248        577.0        1374.0          ['id:twitter.com:2885810856']
# 249        579.0        1383.0          ['id:twitter.com:2885810856']
# 250        584.0        1389.0           ['id:twitter.com:225941295']
# 251        585.0        1390.0           ['id:twitter.com:225941295']
# 252        587.0        1410.0  ['id:twitter.com:806408086319611904']
# 253        588.0        1411.0          ['id:twitter.com:2885810856']
# 254        590.0        1413.0  ['id:twitter.com:806361696684097536']
# 255        591.0        1438.0          ['id:twitter.com:2920444615']
# 256        594.0        1481.0          ['id:twitter.com:2454441133']
# 257        595.0        1482.0          ['id:twitter.com:2454441133']
# 258        596.0        1483.0          ['id:twitter.com:1085177612']
# 259        597.0        1491.0           ['id:twitter.com:111751181']
# ...

# %%
loc_filter1= ds.where(ds['time'].str.contains('2017-03')).dropna()
loc_filter1.to_csv('fp_mar_evolve.csv') 
loc_filter1
# Out:
#       Unnamed: 0  Unnamed: 0.1                                 author  \
# 4511      8267.0        9902.0          ['id:twitter.com:1651109402']
# 4512      8269.0        9904.0            ['id:twitter.com:78496728']
# 4513      8270.0        9905.0           ['id:twitter.com:233111874']
# 4514      8272.0        9907.0           ['id:twitter.com:323175177']
# 4515      8273.0        9908.0            ['id:twitter.com:54801818']
# 4516      8276.0        9912.0          ['id:twitter.com:1315924440']
# 4517      8277.0        9913.0          ['id:twitter.com:2243116382']
# 4518      8279.0        9916.0             ['id:twitter.com:1492801']
# 4519      8281.0        9918.0          ['id:twitter.com:2294202577']
# 4520      8283.0        9920.0           ['id:twitter.com:101134067']
# 4521      8284.0        9921.0  ['id:twitter.com:835306174949933056']
# 4522      8286.0        9923.0           ['id:twitter.com:485863894']
# ...
