# %%
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with 4 connections
df = pd.DataFrame({ 'from':['A', 'D'], 'to':['D', 'E']})
df
 
# Build your graph
#G=nx.from_pandas_dataframe(df, 'from', 'to')
G = nx.from_pandas_edgelist(df, source='from', target='to')
# Plot it
#nx.draw(G, with_labels=True, node_size=1500, font_size=25, font_color="yellow", font_weight="bold")
#nx.draw(G, with_labels=True, width=5, edge_color="skyblue", style="solid")

nx.draw(G, with_labels=True, width=2, edge_color="black", style="solid"  )
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with your connections

 
# Circular
#nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.circular_layout(G))
#plt.title("circular")
 
# Random
#nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.random_layout(G))
#plt.title("random")
 
# Spectral
#nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spectral_layout(G))
#plt.title("spectral")
 
# Spring
#nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spring_layout(G))
#plt.title("spring")
df = pd.DataFrame({ 'from':['A', 'E', 'D', 'E'], 'to':['E', 'D', 'B', 'F']})
df
 
# Build your graph
G=nx.nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph())
 
# Fruchterman Reingold
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.fruchterman_reingold_layout(G), arrows=True)
plt.title("fruchterman_reingold")
# Out:
# Text(0.5,1,'fruchterman_reingold')
