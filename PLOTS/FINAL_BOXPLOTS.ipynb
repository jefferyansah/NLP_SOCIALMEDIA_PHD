# %%
import numpy as np

import matplotlib as mpl

import matplotlib.pyplot as plt

import pylab

## agg backend is used to create plot as a .png file

#mpl.use('agg')

import matplotlib.pyplot as plt


KNN =  [0.72,0.77,0.80,0.87,0.89]
SVM =  [0.78,0.81,0.86,0.87,0.89]

plotall= [ KNN, SVM]

# Create a figure instance

fig = plt.figure(1, figsize=(5, 5))


# Create an axes instance

ax = fig.add_subplot(111)

# Create the boxplot

bp = ax.boxplot(plotall)
bp = ax.boxplot(plotall, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = 'red' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
   flier.set(marker='o', color='#e7298a', alpha=0.5)

ax.set_xticklabels(['X_CPT1', 'X_CPT2'], fontsize=15)
ax.set_yticklabels([0.6,0.65,0.7,0.75,0.8,0.85,0.9], fontsize=15)

plt.ylabel("F1 SCORE", fontsize=15)
plt.title(' (a) South Australia (SA)', fontsize=15)
plt.xlabel(" ", fontsize=16)

ax.get_xaxis().tick_bottom()

ax.get_yaxis().tick_left()
#ax.set_aspect(10)
#ax.set_xlim(0.7,5.3)

plt.ylim(ymax = 0.9, ymin = 0.6) #set limist for axes

plt.show()
fig.savefig('bx1.png', bbox_inches='tight')

# %%
import numpy as np

import matplotlib as mpl

import matplotlib.pyplot as plt

import pylab

## agg backend is used to create plot as a .png file

#mpl.use('agg')

import matplotlib.pyplot as plt


KNN = [0.77,0.68,0.71,0.77,0.79]
SVM = [0.74,0.66,0.68,0.73,0.77]

plotall= [ KNN, SVM]

# Create a figure instance

fig = plt.figure(1, figsize=(5, 5))


# Create an axes instance

ax = fig.add_subplot(111)

# Create the boxplot

bp = ax.boxplot(plotall)
bp = ax.boxplot(plotall, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = 'green' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
   flier.set(marker='o', color='#e7298a', alpha=0.5)

ax.set_xticklabels(['X_CPT1', 'X_CPT2'], fontsize=15)
ax.set_yticklabels([0.6,0.65,0.7,0.75,0.8,0.85,0.9], fontsize=15)

plt.ylabel("F1 SCORE", fontsize=15)
plt.title(' (b) Western Australia (WA)', fontsize=15)
#plt.xlabel("Propgation Tree Models", fontsize=16)

ax.get_xaxis().tick_bottom()

ax.get_yaxis().tick_left()
#ax.set_aspect(10)
#ax.set_xlim(0.7,5.3)

plt.ylim(ymax = 0.9, ymin = 0.6) #set limist for axes

plt.show()
fig.savefig('bx2.png', bbox_inches='tight')

# %%
import numpy as np

import matplotlib as mpl

import matplotlib.pyplot as plt

import pylab

## agg backend is used to create plot as a .png file

#mpl.use('agg')

import matplotlib.pyplot as plt


KNN = [0.73,0.68,0.71,0.65,0.63]
SVM = [0.74,0.76,0.67,0.65,0.72]

plotall= [ KNN, SVM]

# Create a figure instance

fig = plt.figure(1, figsize=(5, 5))


# Create an axes instance

ax = fig.add_subplot(111)

# Create the boxplot

bp = ax.boxplot(plotall)
bp = ax.boxplot(plotall, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = 'blue' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
   flier.set(marker='o', color='#e7298a', alpha=0.5)

ax.set_xticklabels(['X_CPT1', 'X_CPT2'], fontsize=15)
ax.set_yticklabels([0.6,0.65,0.7,0.75,0.8,0.85,0.9], fontsize=15)

plt.ylabel("F1 SCORE", fontsize=15)
plt.title(' (c) New South Wales (NSW)', fontsize=15)
#plt.xlabel("Models", fontsize=16)

ax.get_xaxis().tick_bottom()

ax.get_yaxis().tick_left()
#ax.set_aspect(10)
#ax.set_xlim(0.7,5.3)

plt.ylim(ymax = 0.8, ymin = 0.55) #set limist for axes

plt.show()
fig.savefig('bx3.png', bbox_inches='tight')
