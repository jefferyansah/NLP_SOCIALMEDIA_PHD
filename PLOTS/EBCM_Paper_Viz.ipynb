# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

 
objects = ('Indv', 'MV', 'AVG', 'WAvg', 'Max', 'Sum', '', 'C', 'CS')
performance = [0.71, 0.77, 0.76, 0.76, 0.68, 0.76, 0, 0.78, 0.80]

y_pos = [0, 1, 2, 3, 4, 5, 6, 7, 8]

bars = plt.bar(y_pos, performance, align='center', color='w', edgecolor='black', zorder = 3)
plt.xticks(y_pos, objects)

bars[0].set_hatch('+++')
bars[1].set_hatch('xxx')
bars[2].set_hatch('**')
bars[3].set_hatch('////')
bars[4].set_hatch('....')
bars[5].set_hatch('ooo')
bars[7].set_hatch('OO')
bars[8].set_hatch('XXXXXX')


plt.ylim(0.6, 0.81)
plt.yticks(np.arange(0.6, 0.80, 0.05))
plt.ylabel('Average accuracy(%)')


plt.xlim(-1, 9)
plt.xticks(np.arange(0, 9, 1))
#plt.yaxis.set_major_formatter(mtick.PercentFormatter())

# Turn on the minor TICKS, which are required for the minor GRID
plt.minorticks_on()
# Customize the major grid
plt.grid(which='major', linestyle='-', linewidth='0.5', color='grey', zorder = 0)
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='grey', zorder = 0)
# Turn off the display of all ticks.
plt.tick_params(which='both', # Options for both major and minor ticks
                top='off',    # turn off top ticks
                left='off',   # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off', # turn off bottom ticks
                zorder=0,
                labelbottom=True) # turn off bottom labels



import matplotlib
from matplotlib.ticker import FuncFormatter
def to_percent(y, position):
    # Ignore the passed in position. This has the effect of scaling the default
    # tick locations.
    s = str(int(100 * y))
    # The percent symbol needs escaping in latex
    if matplotlib.rcParams['text.usetex'] is True:
        return s + r'$\%$'
    else:
        return s + '%'

# Create the formatter using the function to_percent. This multiplies all the
# default labels by 100, making them all percentages
formatter = FuncFormatter(to_percent)

# Set the formatter
plt.gca().yaxis.set_major_formatter(formatter)

plt.savefig('comparison_all5.pdf', bbox_inches='tight', dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

 
objects = ('MV', 'AVG', 'WAvg', 'Max', 'Sum')

n_methods = 5
err_total = [0.39, 0.40, 0.39, 0.57, 0.40]
err_c     = [0.29, 0.19, 0.20, 0.13, 0.19]
err_cs    = [0.23, 0.14, 0.15, 0.10, 0.14]


fig, ax = plt.subplots()

index = np.arange(n_methods)
bar_width = 0.3

opacity = 1.0

y_pos1 = [0, 1.3, 2.6, 3.9, 5.2]
#rects1 = ax.bar(index + 0.1, 
rects1 = ax.bar(y_pos1,                
                err_total, 
                bar_width, 
                alpha=opacity, 
                edgecolor='black',
                color='#5b9bd5',
                zorder = 3)


y_pos2 = [0.32, 1.62, 2.92, 4.22, 5.52]
#rects2 = ax.bar(index + 0.1 + bar_width + 0.05, 
rects2 = ax.bar(y_pos2, 
                err_c, 
                bar_width,
                alpha=opacity,
                color='w',
                hatch = 'OO',
                edgecolor='black',
                label='Error using C',
                zorder = 3)

y_pos3 = [0.64, 1.94, 3.24, 4.54, 5.84]
rects3 = ax.bar(y_pos3, 
                err_cs, 
                bar_width,
                alpha=opacity, 
                color='w',
                hatch = 'XXXXXX',  
                edgecolor='black',
                label='Error using CS',
                zorder = 3)


ax.set_ylabel('Error (%)')
ax.set_xticks(y_pos2)
ax.set_xticklabels(('MV', 'AVG', 'WAvg', 'Max', 'Sum'))
ax.legend()



# Turn on the minor TICKS, which are required for the minor GRID
plt.minorticks_on()
# Customize the major grid
plt.grid(which='major', linestyle='-', linewidth='0.5', color='grey', zorder = 0)
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='grey', zorder = 0)
# Turn off the display of all ticks.
plt.tick_params(which='both', # Options for both major and minor ticks
                top='off',    # turn off top ticks
                left='off',   # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off', # turn off bottom ticks
                zorder=0,
                labelbottom=True) # turn off bottom labels



import matplotlib
from matplotlib.ticker import FuncFormatter
def to_percent(y, position):
    # Ignore the passed in position. This has the effect of scaling the default
    # tick locations.
    s = str(int(100 * y))
    # The percent symbol needs escaping in latex
    if matplotlib.rcParams['text.usetex'] is True:
        return s + r'$\%$'
    else:
        return s + '%'

# Create the formatter using the function to_percent. This multiplies all the
# default labels by 100, making them all percentages
formatter = FuncFormatter(to_percent)

# Set the formatter
plt.gca().yaxis.set_major_formatter(formatter)


fig.tight_layout()

plt.savefig('improvement.pdf', bbox_inches='tight', dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

 
objects = ('Indv', 'MV', 'AVG', 'WAvg', 'Max', 'Sum', '', 'C', 'CS')
ranks = [7.13, 3.88, 4.88, 4.25, 7.88, 4.88, 0, 2.06, 1.06]

y_labels = ['7.13', '3.88', '4.88', '4.25', '7.88', '4.88', '', '2.06', '1.06']


y_pos = [0, 1, 2, 3, 4, 5, 6, 7, 8]

bars = plt.bar(y_pos, ranks, align='center', color='w', edgecolor='black', zorder = 3)

plt.xticks(y_pos, objects)

#ind = np.arange(len(performance))  # the x locations for the groups
#plt.yticks(ind+0.15)

bars[0].set_hatch('+++')
bars[1].set_hatch('xxx')
bars[2].set_hatch('**')
bars[3].set_hatch('////')
bars[4].set_hatch('....')
bars[5].set_hatch('ooo')
bars[7].set_hatch('OO')
bars[8].set_hatch('XXXXXX')


plt.ylim(0, 8.5)
plt.yticks(np.arange(0, 8.5, 1))
plt.ylabel('Average rank')


plt.xlim(-1, 9)
plt.xticks(np.arange(0, 9, 1))
#plt.yaxis.set_major_formatter(mtick.PercentFormatter())

# Turn on the minor TICKS, which are required for the minor GRID
plt.minorticks_on()
# Customize the major grid
plt.grid(which='major', linestyle='-', linewidth='0.5', color='grey', zorder = 0)
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='grey', zorder = 0)
# Turn off the display of all ticks.
plt.tick_params(which='both', # Options for both major and minor ticks
                top='off',    # turn off top ticks
                left='off',   # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off', # turn off bottom ticks
                zorder=0,
                labelbottom=True) # turn off bottom labels




# Text on the top of each barplot
for i in range(len(ranks)):
    plt.text(x = y_pos[i]-0.27, y = ranks[i]+0.1, s = y_labels[i], size = 9)

    

plt.hlines(3.25,-1, 9, linewidth=0.6, zorder=4)
plt.text(6.4, 2.95, "CD=3.25," r"$\alpha=0.10$")

plt.hlines(3.46,-1, 9, linestyles="dashed", linewidth=0.6, zorder=4)
plt.text(6.4, 3.52, "CD=3.46," r"$\alpha=0.05$")
#plt.show()    
    
plt.savefig('bonferoni_dunn2.pdf', bbox_inches='tight', dpi=300)
plt.show()
