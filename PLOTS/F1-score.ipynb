# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
plt.rcParams['font.weight'] = 'bold'
# set width of bar
barWidth = 0.11
#rc('axes', linewidth=2)
# set height of bar
bars1 = [0.82, 0.53, 0.64]
bars2 = [0.63, 0.41, 0.52]
bars3 = [0.41, 0.24, 0.23]
bars4 = [0.54, 0.34, 0.41]
bars5 = [0.51, 0.38, 0.37]


 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

 
# Make the plot
plt.bar(r1, bars1, color='black', width=barWidth, edgecolor='white', label='StoryGraph', hatch='\\')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='black', label='TwitInfo', hatch='XXXX')
plt.bar(r3, bars3, color='dodgerblue', width=barWidth, edgecolor='black', label='LDA+Tmp', hatch='-')
plt.bar(r4, bars4, color='orange', width=barWidth, edgecolor='black', label='ConnectingDots', hatch='^' )
plt.bar(r5, bars5, color='darkgrey', width=barWidth, edgecolor='black', label='EventGraph', hatch='o' )
 

# Add xticks on the middle of the group bars
#plt.xlabel('Models', fontweight='bold')
plt.ylabel('F1-Score', fontsize=14, fontweight='bold'  )
plt.xticks([r + barWidth for r in range(len(bars1))], ['Rogue-1', 'Rogue-2', 'Rogue-L',], fontsize= '14', fontweight='bold')
 
# Create legend & Show graphic

plt.ylim(0, 1.0)
plt.title('Fp-Datasets', fontsize=14, fontweight='bold' )
plt.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.60, 0.99),fontsize=11 )
plt.savefig('f1score.png', bbox_inches='tight', dpi=500)
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
plt.rcParams['font.weight'] = 'bold'
 
# set width of bar
barWidth = 0.11
 
# set height of bar
bars1 = [0.71, 0.51, 0.61]
bars2 = [0.44, 0.31, 0.30]
bars3 = [0.32, 0.20, 0.23]
bars4 = [0.6, 0.26, 0.33]
bars5 = [0.53, 0.28, 0.31]


 
# Set position of bar on X axis
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

 
# Make the plot
plt.bar(r1, bars1, color='black', width=barWidth, edgecolor='white', label='StoryGraph', hatch='\\')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='black', label='TwitInfo', hatch='XXXX')
plt.bar(r3, bars3, color='dodgerblue', width=barWidth, edgecolor='black', label='LDA+Tmp', hatch='-')
plt.bar(r4, bars4, color='orange', width=barWidth, edgecolor='black', label='ConnectingDots', hatch='^' )
plt.bar(r5, bars5, color='darkgrey', width=barWidth, edgecolor='black', label='EventGraph', hatch='o' )
 

# Add xticks on the middle of the group bars
#plt.xlabel('Models', fontweight='bold')
plt.ylabel('F1-Score', fontsize=14, fontweight='bold'  )
plt.xticks([r + barWidth for r in range(len(bars1))], ['Rogue-1', 'Rogue-2', 'Rogue-L',], fontsize= '14', fontweight='bold')
 
# Create legend & Show graphic

plt.ylim(0, 1.0)
plt.title('LiveExports Datasets', fontsize=14 , fontweight='bold' )
plt.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.60, 0.99), fontsize=11)
plt.savefig('f2score.png', bbox_inches='tight', dpi=500)
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
plt.rcParams['font.weight'] = 'bold'
 
# set width of bar
barWidth = 0.11
 
# set height of bar
bars1 = [0.91, 0.51, 0.71]
bars2 = [0.54, 0.32, 0.33]
bars3 = [0.34, 0.21, 0.32]
bars4 = [0.54, 0.29, 0.42]
bars5 = [0.44, 0.31, 0.45]

 
# Set position of bar on X axis
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

 
# Make the plot
plt.bar(r1, bars1, color='black', width=barWidth, edgecolor='white', label='StoryGraph', hatch='\\')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='black', label='TwitInfo', hatch='XXXX')
plt.bar(r3, bars3, color='dodgerblue', width=barWidth, edgecolor='black', label='LDA+Tmp', hatch='-')
plt.bar(r4, bars4, color='orange', width=barWidth, edgecolor='black', label='ConnectingDots', hatch='^' )
plt.bar(r5, bars5, color='darkgrey', width=barWidth, edgecolor='black', label='EventGraph', hatch='o' )
 

# Add xticks on the middle of the group bars
#plt.xlabel('Models', fontweight='bold')
plt.ylabel('F1-Score', fontsize=14 ,fontweight='bold' )
plt.xticks([r + barWidth for r in range(len(bars1))], ['Rogue-1', 'Rogue-2', 'Rogue-L',], fontsize= '14',fontweight='bold')
 
# Create legend & Show graphic

plt.ylim(0, 1.0)
plt.title('USGH Datasets', fontsize=14, fontweight='bold' )
plt.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.55, 0.99),fontsize=11)
plt.savefig('f3score.png', bbox_inches='tight', dpi=500)
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
plt.rcParams['font.weight'] = 'bold'
 
# set width of bar
barWidth = 0.11
 
# set height of bar
bars1 = [0.62, 0.75, 0.84]
bars2 = [0.61, 0.59, 0.30]
bars3 = [0.32, 0.21, 0.32]
bars4 = [0.44, 0.41, 0.43]
bars4 = [0.52, 0.48, 0.51]

 
# Set position of bar on X axis
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

 
# Make the plot
plt.bar(r1, bars1, color='black', width=barWidth, edgecolor='white', label='StoryGraph', hatch='\\')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='black', label='TwitInfo', hatch='XXXX')
plt.bar(r3, bars3, color='dodgerblue', width=barWidth, edgecolor='black', label='LDA+Tmp', hatch='-')
plt.bar(r4, bars4, color='orange', width=barWidth, edgecolor='black', label='ConnectingDots', hatch='^' )
plt.bar(r5, bars5, color='darkgrey', width=barWidth, edgecolor='black', label='EventGraph', hatch='o' )
 

# Add xticks on the middle of the group bars
#plt.xlabel('Models', fontweight='bold')
plt.ylabel('F1-Score', fontsize=14,fontweight='bold'  )
plt.xticks([r + barWidth for r in range(len(bars1))], ['Rogue-1', 'Rogue-2', 'Rogue-L',], fontsize= '14',fontweight='bold')
 
# Create legend & Show graphic

plt.ylim(0, 1.0)
plt.title('USJM Datasets', fontsize=14, fontweight='bold'  )
plt.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.40, 0.99), fontsize=11)
plt.savefig('f4score.png', bbox_inches='tight', dpi=500)
plt.show()
