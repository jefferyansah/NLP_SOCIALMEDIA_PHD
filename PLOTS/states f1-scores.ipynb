# %%
import numpy as np 
import matplotlib as mpl 

import matplotlib.pyplot as plt 
a=[[0.81,0.88,0.79,0.80,0.69], [0.87,0.92,0.85,0.80,0.80]]
b=[[0.81,0.88,0.93,0.76,0.75], [0.81,0.88,0.93,0.76,0.73]]
c=[[0.81,0.86,0.86,0.70,0.73], [0.8,0.86,0.86,0.66,0.73]]
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 8))
axes[0, 0].boxplot(a)
axes[0, 0].set_title('Leadtime1', fontsize=fs)

axes[0, 1].boxplot(b)
axes[0, 1].set_title('LeadTime2', fontsize=fs)

axes[0, 2].boxplot(c)
axes[0, 2].set_title('LeadTime3', fontsize=fs)
fig.suptitle("South Australia")
fig.subplots_adjust(wspace=0.7)
fig.subplots_adjust(hspace=0.5)
plt.show()
plt.ylim(ymax = 0.95, ymin = 0.50)
#plt.ylabel("F1 SCORE")
#plt.title('New South Wales')
#plt.xlabel("Models")
plt.show()

# Save the figure
#fig.savefig('fig1.png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

# fake data
#fs = 10  # fontsize


a=[[0.81,0.88,0.79,0.80,0.69], [0.87,0.92,0.85,0.80,0.80]]
b=[[0.81,0.88,0.93,0.76,0.75], [0.81,0.88,0.93,0.76,0.73]]
c=[[0.81,0.86,0.86,0.70,0.73], [0.8,0.86,0.86,0.66,0.73]]
d=[29,24,31,12,42]
e=[34,56,31,64,32]
f=[23,25,26,26,38]


fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(4, 4))
axes[0, 0].boxplot(e)
axes[0, 0].set_title('Leadtime1', fontsize=fs)

axes[0, 1].boxplot(f)
axes[0, 1].set_title('LeadTime2', fontsize=fs)

axes[0, 2].boxplot(d)
axes[0, 2].set_title('LeadTime 3', fontsize=fs)

axes[1, 0].boxplot(a, showmeans=True)
axes[1, 0].set_title('LeadTime 1', fontsize=fs)

axes[1, 1].boxplot(b, showmeans=True)
axes[1, 1].set_title('LeadTime 2', fontsize=fs)

axes[1, 2].boxplot(c)
axes[1, 2].set_title('LeadTime 3', fontsize=fs)
fig.suptitle("South Australia")
fig.subplots_adjust(wspace=0.7)
fig.subplots_adjust(hspace=0.5)
plt.show()
